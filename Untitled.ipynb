# %%
import cv2
import numpy as np

# %%
farm_img = cv2.imread('test2.png', cv2.IMREAD_UNCHANGED)
wheat_img = cv2.imread('subimage.png', cv2.IMREAD_UNCHANGED)

# %%
# There are 6 comparison methods to choose from:
# TM_CCOEFF, TM_CCOEFF_NORMED, TM_CCORR, TM_CCORR_NORMED, TM_SQDIFF, TM_SQDIFF_NORMED
# You can see the differences at a glance here:
# https://docs.opencv.org/master/d4/dc6/tutorial_py_template_matching.html
result = cv2.matchTemplate(farm_img, wheat_img, cv2.TM_SQDIFF_NORMED)

# %%
min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(result)

# %%
max_loc = min_loc

# %%
max_val = min_val

# %%
w = wheat_img.shape[1]
h = wheat_img.shape[0]

# %%
cv2.rectangle(farm_img, max_loc, (max_loc[0] + w, max_loc[1] + h), (0,255,255), 2)
# Out:
# array([[[ 59, 139, 164, 255],
#         [ 68, 150, 169, 255],
#         [ 96, 177, 185, 255],
#         ...,
#         [ 66,  11,   6, 255],
#         [ 67,  10,   6, 255],
#         [ 67,  10,   6, 255]],
#
#        [[ 94, 162, 185, 255],
#         [115, 180, 196, 255],
#         [132, 194, 198, 255],
#         ...,
#         [ 65,  10,   4, 255],
#         [ 68,  11,   5, 255],
#         [ 68,  11,   5, 255]],
#
#        [[120, 178, 200, 255],
#         [136, 189, 203, 255],
#         [154, 204, 206, 255],
#         ...,
#         [ 66,  10,   4, 255],
#         [ 70,  11,   5, 255],
#         [ 70,  11,   5, 255]],
#
#        ...,
#
#        [[ 66,  15,  13, 255],
#         [ 65,  15,  13, 255],
#         [ 63,  15,  12, 255],
#         ...,
#         [255,   0,   0, 255],
#         [255,   0,   0, 255],
#         [255,   0,   0, 255]],
#
#        [[ 67,  15,  14, 255],
#         [ 65,  15,  14, 255],
#         [ 63,  15,  14, 255],
#         ...,
#         [255,   0,   0, 255],
# ...

# %%
threshold = 1
yloc, xloc = np.where(result >= threshold)
for (x, y) in zip(xloc, yloc):
    cv2.rectangle(farm_img, (x, y), (x + w, y + h), (0,255,255), 2)

# %%
cv2.imshow('Farm', farm_img)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
# What is a rectangle?
# x, y, w, h
rectangles = []
for (x, y) in zip(xloc, yloc):
    rectangles.append([int(x), int(y), int(w), int(h)])
    rectangles.append([int(x), int(y), int(w), int(h)])

# %%
rectangles, weights = cv2.groupRectangles(rectangles, 1, 0.2)

# %%
max_val
# Out:
# 0.037459611892700195
